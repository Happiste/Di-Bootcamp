# %% [markdown]
# 🌟 Exercise 1 : Understanding Data Visualization
#
# 1 - Data visualization plays a crucial role in data analysis because it transforms raw data into a visual context, such as graphs or charts, making it easier to understand and interpret, identifies trend and pattern and like we say: A picture is worth a thousand rows of data.
#
# > "A picture is worth a thousand rows of data."
#
#
# 2 - Line graphs are ideal for displaying how one variable changes in response to another over a continuous scale

# %% [markdown]
# 🌟 Exercise 2 : Creating a Line Plot for Temperature Variation

# %%
import random as r
import matplotlib.pyplot as plt
temp = [r.randint(20, 40) for x in range(7)]
day = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# day = [x for x in range(len(temp))]

# %%
plt.figure()
plt.plot(day, temp, label='temperature')
plt.xlabel('Days')
plt.ylabel('Temperature in Celsius')
plt.title('Temperature Variation Over Days')
plt.legend()
plt.show()

# %% [markdown]
# 🌟 Exercise 3 : Visualizing Monthly Sales with a Bar Chart

# %%
sales = [r.randint(1000, 5000) for x in range(12)]
month = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
plt.figure(figsize=(14, 6))
plt.bar(month, sales, label='sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales')
plt.legend()
plt.show()

# %% [markdown]
# 🌟 Exercise 4 : Data Visualisation

# %%
import pandas as pd
df = pd.read_csv('sales_data.csv')
df.head()
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %%
df['revenue'].isnull().sum()
# Out:
# 1

# %%
df['quantity'].sum()
# Out:
# 5360.0

# %%
filter = df.groupby('category')['revenue'].sum()
filter
# Out:
# category
# Accessories    104700.0
# Bags            19500.0
# Bgas              900.0
# Clohting         1200.0
# Clothing        94350.0
# Electronics    516080.0
# Shoes           20640.0
# Shoeses           960.0
# Name: revenue, dtype: float64

# %%
filter.idxmax()
# Out:
# 'Electronics'

# %%
avg_revenue = df['revenue'].mean()
avg_revenue
# Out:
# 2060.679347826087

# %%
df.head()
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %%
df['date']= pd.to_datetime(df['date'], errors='coerce')
df.head()
# Out:
#         date     product     category   price  quantity  revenue
# 0 2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1 2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2 2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3 2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4 2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %%
df['quarter'] = df['date'].dt.quarter
df.head()
# Out:
#         date     product     category   price  quantity  revenue  quarter
# 0 2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0        1
# 1 2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0        1
# 2 2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0        1
# 3 2022-01-03  Headphones  Electronics   100.0      20.0   2000.0        1
# 4 2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0        1

# %%
quarter_revenue = df.groupby('quarter')['revenue'].sum()
quarter_revenue
# Out:
# quarter
# 1    182100.0
# 2    183970.0
# 3    197680.0
# 4    194580.0
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.bar(quarter_revenue.index, quarter_revenue.values, label='revenue')
plt.xlabel('Quarter')
plt.ylabel('Revenue')
plt.title('Quarterly Revenue')
plt.legend()
plt.show()

# %% [markdown]
# 🌟 Exercise 5 : Data Visualisation Using MatPlotLib

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-10, 11)
y = x**2

plt.plot(x, y, label='y=x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Quadratic Function')
plt.legend()
plt.grid(True)
Qplt.show()

# %%
categories = ['A', 'B', 'C', 'D']
sales = [15, 30, 45, 20]
plt.figure(figsize=(12, 6))
plt.bar(categories, sales)
plt.xlabel('week')
plt.ylabel('Sales')
plt.title('weekly Sales')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
percentages = [40, 30, 20, 10]
colors = ['red', 'yellow', 'pink', 'brown']

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(percentages, labels=fruits, colors=colors)
plt.title('Favorite Fruits Distribution')
plt.legend(fruits, title="Fruits", loc="upper left")
plt.show()

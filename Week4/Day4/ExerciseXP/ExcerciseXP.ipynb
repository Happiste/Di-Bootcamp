# %% [markdown]
# 🌟 Exercise 1: Duplicate Detection and Removal

# %%
import pandas as pd

train_data = pd.read_csv('train.csv')
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.duplicated().sum()
# 0 duplicate
# Out:
# 0

# %%
#just to be sure:
train_data = train_data.drop_duplicates()
train_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 🌟 Exercise 2: Handling Missing Values

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_data.drop(columns=['Ticket'], inplace=True)
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
train_data['Cabin'] =train_data['Cabin'].fillna('Unknown')
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Cabin        891 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
from sklearn.impute import SimpleImputer
age_imputer = SimpleImputer(strategy='median')
train_data['Age'] = age_imputer.fit_transform(train_data[['Age']])
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Cabin        891 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
train_data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
train_data['Embarked'].dtype
# Out:
# dtype('O')

# %%
train_data['Embarked'] = train_data['Embarked'].astype(str)

# %%
embarked_imputer = SimpleImputer(strategy='most_frequent')

# %%
train_data['Embarked'] = train_data['Embarked'].fillna(train_data['Embarked'].mode()[0])

train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Cabin        891 non-null    object
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %% [markdown]
# 🌟 Exercise 3: Feature Engineering

# %%
train_data['FamilySize'] = train_data['SibSp'] + train_data['Parch'] + 1

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare    Cabin Embarked  FamilySize
# 0      0   7.2500  Unknown        S           2
# 1      0  71.2833      C85        C           2
# 2      0   7.9250  Unknown        S           1
# 3      0  53.1000     C123        S           2
# 4      0   8.0500  Unknown        S           1

# %%
train_data['Title'] = train_data['Name'].str.split(',').str[1].str.split('.').str[0].str.strip()
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare    Cabin Embarked  FamilySize Title
# 0      0   7.2500  Unknown        S           2    Mr
# 1      0  71.2833      C85        C           2   Mrs
# 2      0   7.9250  Unknown        S           1  Miss
# 3      0  53.1000     C123        S           2   Mrs
# ...

# %%
train_data['Sex'] = train_data['Sex'].map({'male': 0, 'female': 1})
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#       Fare    Cabin Embarked  FamilySize Title
# 0   7.2500  Unknown        S           2    Mr
# 1  71.2833      C85        C           2   Mrs
# 2   7.9250  Unknown        S           1  Miss
# 3  53.1000     C123        S           2   Mrs
# 4   8.0500  Unknown        S           1    Mr

# %%
from sklearn.preprocessing import LabelEncoder
train_data['Embarked'] = LabelEncoder().fit_transform(train_data['Embarked'])
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#       Fare    Cabin  Embarked  FamilySize Title
# 0   7.2500  Unknown         2           2    Mr
# 1  71.2833      C85         0           2   Mrs
# 2   7.9250  Unknown         2           1  Miss
# 3  53.1000     C123         2           2   Mrs
# 4   8.0500  Unknown         2           1    Mr

# %%
train_data['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
train_data[['Fare_normalize']] = MinMaxScaler().fit_transform(train_data[['Fare']])

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#       Fare    Cabin  Embarked  FamilySize Title  Fare_normalize
# 0   7.2500  Unknown         2           2    Mr        0.014151
# 1  71.2833      C85         0           2   Mrs        0.139136
# 2   7.9250  Unknown         2           1  Miss        0.015469
# ...

# %%
from sklearn.preprocessing import StandardScaler
train_data[['Age_standardize']] = StandardScaler().fit_transform(train_data[['Age']])

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#       Fare    Cabin  Embarked  FamilySize Title  Fare_normalize  \
# 0   7.2500  Unknown         2           2    Mr        0.014151
# 1  71.2833      C85         0           2   Mrs        0.139136
# 2   7.9250  Unknown         2           1  Miss        0.015469
# ...

# %% [markdown]
# 🌟 Exercise 4: Outlier Detection and Handling

# %%
train_data['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
Q1 = train_data['Fare'].quantile(0.25)
Q1
# Out:
# 7.9104

# %%
Q3 = train_data['Fare'].quantile(0.75)
Q3
# Out:
# 31.0

# %%
IQR = Q3 - Q1
IQR
# Out:
# 23.0896

# %%
outlier_condition = (train_data['Fare'] < (Q1 - 1.5 * IQR)) | (train_data['Fare'] > (Q3 + 1.5 * IQR))
outlier_condition.sum()
# Out:
# 116

# %%
import numpy as np
train_data['Fare_Log'] = train_data['Fare'].apply(lambda x: np.log(x + 1))

# %%
# train_data.head()

# %%
Q1 = train_data['Age'].quantile(0.25)
Q3 = train_data['Age'].quantile(0.75)
IQR = Q3 - Q1

# %%
outlier_condition = (train_data['Age'] < (Q1 - 1.5 * IQR)) | (train_data['Age'] > (Q3 + 1.5 * IQR))
outlier_condition.sum()
# Out:
# 66

# %%
train_data['Age'].describe()
# Out:
# count    891.000000
# mean      29.361582
# std       13.019697
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# 🌟 Exercise 5: Data Standardization and Normalization

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PassengerId      891 non-null    int64
#  1   Survived         891 non-null    int64
#  2   Pclass           891 non-null    int64
#  3   Name             891 non-null    object
#  4   Sex              891 non-null    int64
#  5   Age              891 non-null    float64
#  6   SibSp            891 non-null    int64
#  7   Parch            891 non-null    int64
#  8   Fare             891 non-null    float64
#  9   Cabin            891 non-null    object
#  10  Embarked         891 non-null    int64
#  11  FamilySize       891 non-null    int64
#  12  Title            891 non-null    object
#  13  Fare_normalize   891 non-null    float64
#  14  Age_standardize  891 non-null    float64
#  15  Fare_Log         891 non-null    float64
# dtypes: float64(5), int64(8), object(3)
# ...

# %%
train_data.describe()
#tout est deja standardise/normalise
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.352413   29.361582
# std     257.353842    0.486592    0.836071    0.477990   13.019697
# min       1.000000    0.000000    1.000000    0.000000    0.420000
# 25%     223.500000    0.000000    2.000000    0.000000   22.000000
# 50%     446.000000    0.000000    3.000000    0.000000   28.000000
# 75%     668.500000    1.000000    3.000000    1.000000   35.000000
# max     891.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch        Fare    Embarked  FamilySize  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208    1.538721    1.904602
# std      1.102743    0.806057   49.693429    0.794231    1.613459
# min      0.000000    0.000000    0.000000    0.000000    1.000000
# ...

# %% [markdown]
# 🌟 Exercise 6: Feature Encoding
# already done before

# %% [markdown]
# 🌟 Exercise 7: Data Transformation for Age Feature

# %%
train_data['AgeGroup'] = pd.cut(train_data['Age'], bins=[0, 18, 50, 80], labels=['Child', 'Adult', 'Senior'])

# %%
train_data[['Age', 'AgeGroup']].head(15)
# Out:
#      Age AgeGroup
# 0   22.0    Adult
# 1   38.0    Adult
# 2   26.0    Adult
# 3   35.0    Adult
# 4   35.0    Adult
# 5   28.0    Adult
# 6   54.0   Senior
# 7    2.0    Child
# 8   27.0    Adult
# 9   14.0    Child
# 10   4.0    Child
# 11  58.0   Senior
# 12  20.0    Adult
# 13  39.0    Adult
# 14  14.0    Child

# %%
train_data['AgeGroup'].value_counts()
# Out:
# AgeGroup
# Adult     688
# Child     139
# Senior     64
# Name: count, dtype: int64

# %%
train_data = pd.get_dummies(train_data, columns=['AgeGroup'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-442-19edd1c57061> in <cell line: 1>()
# ----> 1 train_data = pd.get_dummies(train_data, columns=['AgeGroup'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
# ...

# %%
train_data.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name  Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    0  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                              Heikkinen, Miss. Laina    1  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# ...

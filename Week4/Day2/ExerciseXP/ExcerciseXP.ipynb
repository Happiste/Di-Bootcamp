# %% [markdown]
# ### Excercise 2&3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

time = pd.read_csv('Time Americans Spend Sleeping.csv')
mental_healt = pd.read_csv('Mental health Depression disorder Data.csv', low_memory=False)
clean_dataset = pd.read_csv('clean_dataset.csv')
crx = pd.read_csv('crx.csv')

# %%
time.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
time.describe()
# Out:
#             index         Year  Avg hrs per day sleeping  Standard Error
# count  945.000000   945.000000                945.000000      945.000000
# mean   472.000000  2010.000000                  8.806868        0.086958
# std    272.942302     4.322782                  0.545001        0.034631
# min      0.000000  2003.000000                  7.720000        0.018000
# 25%    236.000000  2006.000000                  8.360000        0.063000
# 50%    472.000000  2010.000000                  8.810000        0.084000
# 75%    708.000000  2014.000000                  9.190000        0.106000
# max    944.000000  2017.000000                 10.650000        0.228000

# %%
time.dtypes
# Out:
# index                         int64
# Year                          int64
# Period                       object
# Avg hrs per day sleeping    float64
# Standard Error              float64
# Type of Days                 object
# Age Group                    object
# Activity                     object
# Sex                          object
# dtype: object

# %%
for column in time.columns:
    dtype = time[column].dtype
    if pd.api.types.is_numeric_dtype(dtype):
        print(f"{column}: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)")
    else:
        print(f"{column}: Qualitative (Reason: Données catégoriques ou descriptives)")
# Out:
# index: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# Year: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# Period: Qualitative (Reason: Données catégoriques ou descriptives)
# Avg hrs per day sleeping: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# Standard Error: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# Type of Days: Qualitative (Reason: Données catégoriques ou descriptives)
# Age Group: Qualitative (Reason: Données catégoriques ou descriptives)
# Activity: Qualitative (Reason: Données catégoriques ou descriptives)
# Sex: Qualitative (Reason: Données catégoriques ou descriptives)

# %%
mental_healt.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %%
mental_healt.describe()
# Out:
#                index  Anxiety disorders (%)  Drug use disorders (%)  \
# count  108553.000000            6468.000000             6468.000000
# mean    54276.000000               3.989921                0.862278
# std     31336.696223               1.167526                0.460679
# min         0.000000               2.023393                0.383650
# 25%     27138.000000               3.188824                0.535064
# 50%     54276.000000               3.554373                0.726430
# 75%     81414.000000               4.682163                0.940157
# max    108552.000000               8.967330                3.452476
#
#        Depression (%)  Alcohol use disorders (%)
# count     6468.000000                6468.000000
# mean         3.497654                   1.585821
# std          0.655859                   0.860283
# min          2.139903                   0.446940
# 25%          3.005529                   0.993685
# 50%          3.499606                   1.479936
# ...

# %%
mental_healt.dtypes
# Out:
# index                          int64
# Entity                        object
# Code                          object
# Year                          object
# Schizophrenia (%)             object
# Bipolar disorder (%)          object
# Eating disorders (%)          object
# Anxiety disorders (%)        float64
# Drug use disorders (%)       float64
# Depression (%)               float64
# Alcohol use disorders (%)    float64
# dtype: object

# %%
for column in mental_healt.columns:
    dtype = mental_healt[column].dtype
    if pd.api.types.is_numeric_dtype(dtype):
        print(f"{column}: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)")
    else:
        print(f"{column}: Qualitative (Reason: Données catégoriques ou descriptives)")

# %%
clean_dataset.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
clean_dataset.describe()
# Out:
#            Gender         Age        Debt     Married  BankCustomer  \
# count  690.000000  690.000000  690.000000  690.000000    690.000000
# mean     0.695652   31.514116    4.758725    0.760870      0.763768
# std      0.460464   11.860245    4.978163    0.426862      0.425074
# min      0.000000   13.750000    0.000000    0.000000      0.000000
# 25%      0.000000   22.670000    1.000000    1.000000      1.000000
# 50%      1.000000   28.460000    2.750000    1.000000      1.000000
# 75%      1.000000   37.707500    7.207500    1.000000      1.000000
# max      1.000000   80.250000   28.000000    1.000000      1.000000
#
#        YearsEmployed  PriorDefault    Employed  CreditScore  DriversLicense  \
# count     690.000000    690.000000  690.000000    690.00000      690.000000
# mean        2.223406      0.523188    0.427536      2.40000        0.457971
# std         3.346513      0.499824    0.495080      4.86294        0.498592
# ...

# %%
clean_dataset.dtypes
# Out:
# Gender              int64
# Age               float64
# Debt              float64
# Married             int64
# BankCustomer        int64
# Industry           object
# Ethnicity          object
# YearsEmployed     float64
# PriorDefault        int64
# Employed            int64
# CreditScore         int64
# DriversLicense      int64
# Citizen            object
# ZipCode             int64
# Income              int64
# Approved            int64
# dtype: object

# %%
for column in clean_dataset.columns:
    dtype = clean_dataset[column].dtype
    if pd.api.types.is_numeric_dtype(dtype):
        print(f"{column}: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)")
    else:
        print(f"{column}: Qualitative (Reason: Données catégoriques ou descriptives)")
# Out:
# Gender: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# Age: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# Debt: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# Married: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# BankCustomer: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# Industry: Qualitative (Reason: Données catégoriques ou descriptives)
# Ethnicity: Qualitative (Reason: Données catégoriques ou descriptives)
# YearsEmployed: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# PriorDefault: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# Employed: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# CreditScore: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# ...

# %%
crx.head()
# Out:
#    b  30.83      0  u  g  w  v  1.25  t t.1  01  f g.1  00202  0.1  +
# 0  a  58.67  4.460  u  g  q  h  3.04  t   t   6  f   g  00043  560  +
# 1  a  24.50  0.500  u  g  q  h  1.50  t   f   0  f   g  00280  824  +
# 2  b  27.83  1.540  u  g  w  v  3.75  t   t   5  t   g  00100    3  +
# 3  b  20.17  5.625  u  g  w  v  1.71  t   f   0  f   s  00120    0  +
# 4  b  32.08  4.000  u  g  m  v  2.50  t   f   0  t   g  00360    0  +

# %%
crx.describe()
# Out:
#                 0        1.25          01            0.1
# count  689.000000  689.000000  689.000000     689.000000
# mean     4.765631    2.224819    2.402032    1018.862119
# std      4.978470    3.348739    4.866180    5213.743149
# min      0.000000    0.000000    0.000000       0.000000
# 25%      1.000000    0.165000    0.000000       0.000000
# 50%      2.750000    1.000000    0.000000       5.000000
# 75%      7.250000    2.625000    3.000000     396.000000
# max     28.000000   28.500000   67.000000  100000.000000

# %%
crx.dtypes
# Out:
# b         object
# 30.83     object
# 0        float64
# u         object
# g         object
# w         object
# v         object
# 1.25     float64
# t         object
# t.1       object
# 01         int64
# f         object
# g.1       object
# 00202     object
# 0.1        int64
# +         object
# dtype: object

# %%
for column in crx.columns:
    dtype = crx[column].dtype
    if pd.api.types.is_numeric_dtype(dtype):
        print(f"{column}: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)")
    else:
        print(f"{column}: Qualitative (Reason: Données catégoriques ou descriptives)")
# Out:
# b: Qualitative (Reason: Données catégoriques ou descriptives)
# 30.83: Qualitative (Reason: Données catégoriques ou descriptives)
# 0: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# u: Qualitative (Reason: Données catégoriques ou descriptives)
# g: Qualitative (Reason: Données catégoriques ou descriptives)
# w: Qualitative (Reason: Données catégoriques ou descriptives)
# v: Qualitative (Reason: Données catégoriques ou descriptives)
# 1.25: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# t: Qualitative (Reason: Données catégoriques ou descriptives)
# t.1: Qualitative (Reason: Données catégoriques ou descriptives)
# 01: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)
# f: Qualitative (Reason: Données catégoriques ou descriptives)
# g.1: Qualitative (Reason: Données catégoriques ou descriptives)
# 00202: Qualitative (Reason: Données catégoriques ou descriptives)
# ...

# %% [markdown]
# ###Excercise 4 Iris Data set:

# %%
iris = pd.read_csv('/content/Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
for column in iris.columns:
  dtypes = iris[i].dtype
  if pd.api.types.is_numeric_dtype(dtypes):
    print(f"{column}: Quantitative (Reason: Valeurs numériques représentant des mesures ou des comptes)")
  else:
    print(f"{column}: Qualitative (Reason: Données catégoriques ou descriptives)")
# Out:
# Id: Qualitative (Reason: Données catégoriques ou descriptives)
# SepalLengthCm: Qualitative (Reason: Données catégoriques ou descriptives)
# SepalWidthCm: Qualitative (Reason: Données catégoriques ou descriptives)
# PetalLengthCm: Qualitative (Reason: Données catégoriques ou descriptives)
# PetalWidthCm: Qualitative (Reason: Données catégoriques ou descriptives)
# Species: Qualitative (Reason: Données catégoriques ou descriptives)

# %% [markdown]
# ###Excercise5

# %%
mean_value = clean_dataset['CreditScore'].mean()
mean_value
# Out:
# 2.4

# %%
median_value = clean_dataset['CreditScore'].median()
median_value
# Out:
# 0.0

# %%
mode_value = clean_dataset['CreditScore'].mode()
mode_value
# Out:
# 0    0
# Name: CreditScore, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.histplot(clean_dataset['Age'], bins=8, kde=True, color='red', alpha=0.5)
plt.title("Histogram of Quantitative Data", fontsize=16)
plt.xlabel("age", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ###Excercise 6

# %% [markdown]
# ##🌟 Exercise 1 : Linear Regression Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import pearsonr, spearmanr


house_sizes = [50, 70, 80, 100, 120]
house_prices = [150000, 200000, 210000, 250000, 280000]
house_sizes = np.array(house_sizes)
house_prices = np.array(house_prices)
plt.scatter(house_sizes, house_prices, color='blue')
plt.xlabel('House Size')
plt.ylabel('House Price')
plt.title('House Size vs. House Price')
plt.show()

# %% [markdown]
# What is the slope and intercept of the regression line?

# %%
slope, intercept = np.polyfit(house_sizes, house_prices, 1)
print(f"Slope: {slope}, Intercept: {intercept.round()}")
# Out:
# Slope: 1828.7671232876705, Intercept: 64384.0

# %% [markdown]
# Predict the price of a house that is 90 square meters.

# %%
price_of_90_square_meters = slope * 90 + intercept
print(f"Price of a house with 90 square meters: {price_of_90_square_meters.round()}")
# Out:
# Price of a house with 90 square meters: 228973.0

# %% [markdown]
# Interpret the meaning of the slope in the context of housing prices.

# %% [markdown]
# The slope indicates how much the price increases for each additional square meter.It is the price per square meter.

# %%
y_pred = slope * house_sizes + intercept

plt.scatter(house_sizes, house_prices, color='blue', label='data')
plt.plot(house_sizes, y_pred, color='red', label='linear regression')

plt.title("Linear regression: Price vs Size")
plt.xlabel("House Size (m²)")
plt.ylabel("House Price")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# ##🌟 Exercise 2 : Understanding ANOVA

# %%
fertilizer_1 = [5, 6, 7, 6, 5]
fertilizer_2 = [7, 8, 7, 9, 8]
fertilizer_3 = [4, 5, 4, 3, 4]

fertilizer_1 = np.array(fertilizer_1)
fertilizer_2 = np.array(fertilizer_2)
fertilizer_3 = np.array(fertilizer_3)

f_statistic, p_value = cp.stats.f_oneway(fertilizer_1, fertilizer_2, fertilizer_3)

print(f"F-statistic: {f_statistic}")
print(f"p-value: {p_value}")
# Out:
# F-statistic: 28.52631578947368
# p-value: 2.7542672098048448e-05

# %% [markdown]
# - Based on the p-value the fertilizers have no significantly effects on plant growth
#
# - If the p-value were above 0.05 this would mean that the fertilizer is effective on plant growth.

# %% [markdown]
# ##🌟 Exercise 3 : Probability Distributions

# %%
from scipy.stats import binom

# Définir les paramètres
n = 10 # Nombre total d'essais
k = 5 # Nombre de succès souhaités
k_4 = 4
k_6 = 6
p = 0.5 # Probabilité de succès à chaque essai

# Calculer la probabilité
probability = binom.pmf(k, n, p)
probability4 = binom.pmf(k_4, n, p)
probability6 = binom.pmf(k_6, n, p)
print(f"La probabilité d'obtenir exactement {k_4} succès est : {probability4}")
print(f"La probabilité d'obtenir exactement {k} succès est : {probability}")
print(f"La probabilité d'obtenir exactement {k_6} succès est : {probability6}")
# Out:
# La probabilité d'obtenir exactement 4 succès est : 0.2050781249999999
# La probabilité d'obtenir exactement 5 succès est : 0.24609375000000003
# La probabilité d'obtenir exactement 6 succès est : 0.2050781249999999

# %%
k_values = range(n + 1)
probabilities = [binom.pmf(k, n, p) for k in k_values]

plt.bar(k_values, probabilities)
plt.xlabel('Success Number')
plt.ylabel('Probability')
plt.title('Binomiale Distribution')
plt.show()

# %% [markdown]
# ##🌟 Exercise 4 : Correlation Coefficients

# %%
data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})
data.head()
# Out:
#    age  income
# 0   23   35000
# 1   25   40000
# 2   30   50000
# 3   35   60000
# 4   40   70000

# %% [markdown]
# Calculate the Pearson and Spearman correlation coefficients between two variables in a dataset.

# %%
pearson_corr = pearsonr(data['age'], data['income'])
spearman_corr = spearmanr(data['age'], data['income'])

print(f"Pearson correlation coefficient: {pearson_corr[0]}")
print(f"Spearman correlation coefficient: {spearman_corr[0]}")
# Out:
# Pearson correlation coefficient: 0.9996907452347202
# Spearman correlation coefficient: 0.9999999999999999

# %% [markdown]
# Insight: Age is strongly related to income in these data.

# %% [markdown]
# ##🌟 Exercise 5 : Linear Relationships

# %%
slope, intercept = np.polyfit(data['age'], data['income'], 1)
print(f"Slope: {slope}, Intercept: {intercept}")


plt.scatter(data['age'], data['income'], label='data')
plt.plot(data['age'], slope * data['age'] + intercept, color='red', label='Linear regression')
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Age vs. Income with linear regression')
plt.legend()
plt.show()
# Out:
# Slope: 2038.5395537525344, Intercept: -11379.310344827565
